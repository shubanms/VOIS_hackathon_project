# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread('assets\\images\\00000000.jpg')

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# B G R format
# Out:
# (512, 512, 3)

# %%
plt.imshow(image)

# %%
new_image = cv2.cvtColor(image , cv2.COLOR_BGR2RGB)

plt.imshow(new_image)

# %%
new_image.shape
# Out:
# (512, 512, 3)

# %%
# Splitting the image channel

r , g , b = cv2.split(new_image)

print("R" , r)
print("G" , g)
print("B" , b)

r.shape
g.shape
b.shape
# Out:
# R [[162 162 162 ... 159 158 158]
#  [162 162 162 ... 167 166 166]
#  [162 162 162 ... 175 175 175]
#  ...
#  [194 182 197 ... 191 183 174]
#  [189 179 189 ... 188 182 173]
#  [140 144 159 ... 186 188 184]]
# G [[154 154 154 ... 157 156 156]
#  [154 154 154 ... 165 164 164]
#  [154 154 154 ... 173 173 173]
#  ...
#  [185 173 188 ... 183 175 166]
#  [180 170 180 ... 180 174 165]
#  [131 135 150 ... 178 180 176]]
# B [[143 143 143 ... 145 144 144]
#  [143 143 143 ... 153 152 152]
#  [143 143 143 ... 161 161 161]
#  ...
#  [176 164 179 ... 170 162 153]
#  [171 161 171 ... 167 161 152]
#  [122 126 141 ... 165 167 163]]
# (512, 512)

# %%
new_image = cv2.merge((r,g,b))
